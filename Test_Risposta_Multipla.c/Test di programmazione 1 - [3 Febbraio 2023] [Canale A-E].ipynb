# %% [markdown]
# ![Pagina 1](pdf_images/page_1.png)
# ![Pagina 2](pdf_images/page_2.png)
# ![Pagina 3](pdf_images/page_3.png)
# ![Pagina 4](pdf_images/page_4.png)
# ![Pagina 5](pdf_images/page_5.png)
# ![Pagina 6](pdf_images/page_6.png)
# ![Pagina 7](pdf_images/page_7.png)
# ![Pagina 8](pdf_images/page_8.png)
# ![Pagina 9](pdf_images/page_9.png)
# ![Pagina 10](pdf_images/page_10.png)

# %% [markdown]
# # Spiegazione Soluzioni

# %% [markdown]
# # Linker :
# Il compito del linker è quello di riuscire a combinare i vari moduli oggetto file generati dal compilatore in un unico file eseguibile.
# Ricordando come avviene la compilazione in un file C:
# PreProcessing: il preprocessore elabora il codice sorgente gestendo direttive quali ad esempio librerie, macro...
# Compiling: il compilatore (nel caso di c gcc) traduce il codice sorgente pre-processato in codice-assembly.
# Assembling: l'assembler converte il codice assembly in codice oggetto, non ancora un eseguibile completo.
# Linking(linker) : il linker prende uno o più file oggetto e li combina in un unico file eseguibile.
#
# # Siano a e b due variabili di tipo int. Il risultato della seguente espressione: rand() % (b-a+1) + a
#
# Dalla teoria si vede che quest'ultima è la formula per ritornare un numero randomico tra due estremi a(numero minore) e b(numero maggiore) INCLUSI.
#
# # L'operatore di dereferenziazione e':
#
# L'operatore di dereferenziazione e': *
# Per chiunque fosse confuso l'operatore & è l'operatore di referenziazione
#
# # La seguente codifica di controllo (sia N un intero positivo): for(int i=1; i<N+1;
# i++
#
# Si noti che in questo ciclo for la i parte da 1 e che si arriva fino ad N+1.
# Se normalmente con for(int i=0; i<N;i++) facciamo N iterazione se aumentiamo di 1 sia l'inizializzazione che la condizione sempre N iterazioni farà
#
# # La seguente direttiva: #define MAX(a,b) (a>b ? a : b) :
#
# Quest'ultima( che prende il nome di macro) :
# 1) non migliora l'efficienza di una funzione. Evita la chiamata ad una funzione con l'inizializzazione di tutti gli elementi di quest'ultima ma una funzione per il lavoro che svolge sarà più efficiente averla rispetto alla macro
# 2) Non è il compito della macro
# 3) Viene elaborata dal preprocessore prima di ogni altra istruzione( ricordando quanto detto nella prima domanda )
# 4) Vero. Il preprocessore sostituisce tutte le occorenze con l'espressione che costituisce l'ultima parte della direttiva.
# 5)
# # E' corretto memorizzare Il numero 1234.1234  in una variabile di tipo:
#
# 1) double (vero): come vedremo la scelta ricade tra double e float ma il tipo float prende con accuratezza fino a 7 cifre qui ne abbiamo 8 meglio usare un double che ha più accuratezza
# 2) int : spero che non c'è bisogno di spiegare perchè...(essendo il valori in virgola mobile)
# 3) float (falso): come detto prima meglio usare un double
# 4) long int : uguale alla 2)
# 5)
# # Sia x una variabile double. L'espressione (int ) (x + 0.5)
#
# Con (int) stiamo castando il valore double di (x+0.5) all'intero (TENENDO CONTO CHE NON TIENE CONTO SE è .4, .5, .8, arrotonderà sempre per difetto) e per prendere il valore intero più vicino aggiungiamo alla x il valore 0.5 cosicè arrotondi a quello giusto: ( se abbiamo 5.6+0.5=6.1 che castato torna 6 invece 5.3+0.5=5.8=5)
#
# # Un esempio di operatore unario è:
#
# Attenzione: Tutti le successive risposte posso essere usate o come operatori unitari o relazionali (basti pensare all'operatore logico !(NOT) ) , quindi la risposta giustà è quella che sempre sarà utilizzato come operatore unitario.
# 1) operatore relazionale(falso):gli operatori relazionale servono a mettere in relazione due elementi quindi quali: ==, >=, <=
# 2) operatore di dereferenziazione (*): anche questo mette in relazione due elementi
# 3) operatore di decremento: Decrementa sempre un unico elemento
# 4)  operatore logico : quali && o ||: anche in questo caso mettono in relazione due elementi
# 5)
# # La parola chiave struct
#
# 1) permette di estendere un tipo primitivo con ulteriori informazioni: Non permette di estendere un tipo primitivo
# 2)
# permette di definire alias di tipi gia' definit: Non definisce nessun aliasi3)
# permette di definire un campo di b : non definisce un campo di biti4) t
# permette di aggregare un insieme di variabili sotto un unico n: Aggrega variabili quali costanti, puntatori,array,matrici sotto un unico nome
# 5)
# # L'algoritmo denominato Bubble sort :
#
# Ricordando che la definizione di Bubble sort:
# "Il bubble sort è un algoritmo di ordinamento semplice , che funziona confrontando ripetutamente coppie adiacenti di elementi in una lista e scambiandoli se sono nell'ordine sbagliato"
# 1) necessita di operare su una copia dei dati: non necessita di operare su una copia dei dati
# 2)
# opera mediante una successione di scambi (swap) su coppie di dat: vero,opera su scambii3)
# non permette di ordinare stringhe in ordine lessicografi (falso)c4) o
# e' un algoritmo di ordinamento per dati che siano numeri int: non si applica solo a numeri interi
# 5)
# # Una funzione con il seguente prototipo: void f(const int *ptr);
#
# Invito se si hanno dubbi a guardare il file puntatori.c. const intn *ptr --> puntatore ad una costante
# 1) non potra'  modificare il dato puntato da ptr: vero
# 2)
# opera su una copia, sullo stack, dell'intero dato puntato da pt : non opera su una copiar3)
# potra' modificare il dato puntato dal parametro formale p: puntatore a costante non posso modificarlat4) r
# nessuno di que (falso)
# 5) s# La funzione di libreria fopen():
#
# Teoria:
# fopen() serve ad aprire un file in una delle varie modalità (che sia scrittura, lettura o entrambe) ed inserirlo in uno stream:
# Esempio:
# FILE *fp;
#
# fp=fopen(“ coding.txt“, “w+t“
#
# # Sia definita una variabile s nel seguente modo:
#
# char *s = "Pippo";
# indicare quale operazione non sara' ammessa dal compilatore:
#
# Bisogna considerare che quando noi effettuiamo char *s= "Pippo"; stiamo creando una stringa CONSTANTE. Quindi non possiamo modificarla
# 1) printf("%c", s[3]);  stampa il valore, Possibile
# 2)
# s[2] = 'x';Modifica la stringa,IMPOSSIBILE 3)
# printf("%s", s stampa la stringa, Possibile)4) ;
# for(int i=0; i<strlen(s); i++) printf("%c -->", s[i Stampa la stringa mediante un for
# # La tecnica di ricerca binaria (o dicotomica) :
# Teoria:
# La ricerca binaria, o dicotomica, è un algoritmo di ricerca efficiente che viene utilizzato per trovare un elemento specifico all'interno di un insieme di dati ordinati (ad esempio, un array o una lista ordinata). A differenza della ricerca lineare, che controlla ogni elemento uno per uno, la ricerca binaria divide ripetutamente a metà la porzione di array che potrebbe contenere l'elemento cercato, riducendo drasticamente il numero di confronti necessari.
# Esempio: Dizionario
# # Sia definita la seguente funzione:
# double *f(int a, int b)
#   dbuble x = a+(double) b/2 //Alloca x LOCALMENTE NELLO STACK DELLA FUNZIONE,ESISTE SOLO QUA
#    return  // NON POSSO PASSARLA, APPENA CHIUDO LA FUNZIONE SI ELIMINERà DALLO STACK
# x
#
# 1) La funzione contiene codice che potrebbe provocare un grave errore a tempo di esecuzione;
# viene segnalato dal compilatore con un errore : Non viene segnalato un errore ma bensi un waring;2)
# L'espressione calcolata dalla funzione non consente di ottenere un risultato precis : non esattamente;3)
# La funzione contiene codice che potrebbe provocare un grave errore a tempo di esecuzione;
# viene segnalato dal compilatore con un warn giuston4) g;
# I parametri formali della funzione dovrebbero essere ti dipo do: l'errore sta nel ritorno della funzione
# bl# Sia data la seguente dichiarazione:
#
# struct record *ptr = malloc(sizeof(struct record));
#
# Indicare la forma corretta per l'accesso al campo data (sia un int) del recor
#      Per potere accedere ad un campo (ad esempio int) del record si usa l'operatore ->. Andare a guardare la parte sulle struct(struct.c)
# #  Nella struttura dati detta coda:
# Fifo --> first in first out ( immaginate la coda di una banca,il primo che va allo sportello se ne va )
# 1) Se la coda e' non ordinata, non e' possibile inserire un dato in maniera corretta. : Falso si può inserire un dato
# 2)
# Inserimento e cancellazione avvengono con modalita' LIFO.: no, in una cosa avviene FIFO 3)
# Inserimento e cancellazione avvengono con modalita' FIF: veroO4) .
# L'inserimento di un dato avviene in testa oppure in coda, in base all'ordinamento dei da: non è detto essendo dinamica
# # La seguente istruzione:
#
# int **a = malloc(sizeof(int *)*n)
#
# Analizzando vediamo da int **a che o stiamo parlando di una matrice o di un array di puntatori; guardando il resto capiamo (int *) che si sta parlando di un array di puntatori. ( Se si hanno dubbi guardare il file puntatori.c)
# 1) permette di ottenere un doppio puntatore ad un array di int : falso non permette di ottenere un doppio puntatore
# 2)
# permette di allocare un vettore di n puntatori al tipo in : verot3)
# permette di allocare una matrice di interi di dimensione n x: falso non alloca una matrice 4) n
# permette di allocare un vettore di interi di dimension: non alloca solo un vettore di interi
# # Una ipotetica funzione di inserimento per una struttura dati dinamica che sia
# una lista concatenata:
# 1) potrebbe modificare la testa della lista: l'inserimento in testa è un'operazione comune
# 2)
# non potra' ricevere in input una lista vuota falso, una lista vuota è valida e l'inserimento dovrebbe essere possibile;3)
# se la lista e' piena, restituira' NU : essendo dinamica non potrà ritornare NULLL4) L
# potra' inserire solo in c: Una lista concatenata può supportare inserimenti in qualsiasi posizione.oda
#  e n;ti.
# 19e;
#
# }
# ]);e:) ti
# eriometiva
# *

# %%
pip install pymupdf
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fitz  # PyMuPDF
import os

def convert_pdf_to_images(pdf_path, output_folder):
    doc = fitz.open(pdf_path)
    for page_num in range(doc.page_count):
        page = doc[page_num]
        pix = page.get_pixmap()
        output_path = os.path.join(output_folder, f"page_{page_num+1}.png")
        pix.save(output_path)

pdf_file = "Test di programmazione 1 - [3 Febbraio 2023] [Canale A-E].pdf"
output_dir = "pdf_images"  # Crea una cartella per le immagini
os.makedirs(output_dir, exist_ok=True)
convert_pdf_to_images(pdf_file, output_dir)
